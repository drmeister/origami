# %%
(ql:quickload "cl-json")
# Out:
# To load "cl-json":
#   Install 1 Quicklisp release:
#     cl-json
# ...
# 61,399 bytes in 0.02 seconds (2998.00KB/sec)
# ; Loading "cl-json"
# [package json]....................................
# [package json-rpc].........
# ("cl-json")

# %%
(ext:getcwd)
# Out:
# "/home/app/work/home/cando/origami/tommaso/"

# %%
(load "../lib/tools.lisp")
# Out:
# T

# %%
(slime)
# Out:
# SIMPLE-WARNING:
# Add support for proclaim (TYPE LIST *MAILBOXES*)
# #<PROCESS SWANK-MAIN @0x11996649>

# %%
(ext:start-swank)
# Out:
# SIMPLE-WARNING:
# Add support for proclaim (TYPE LIST *MAILBOXES*)
# #<PROCESS SWANK-MAIN @0xf90a469>

# %% [markdown]
# # Test parser

# %%
(defparameter *s* (open "cadnano_test_file/super_barcode_hex.json"  :direction :input))
# Out:
# *S*

# %%
*s*
# Out:
# #<IOSTREAM-STREAM cadnano_test_file/super_barcode_hex.json>

# %%
(defparameter *j* (json:decode-json *s*))
# Out:
# *J*

# %%
(defparameter *origami* (parse-json *j*))
# Out:
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# vstrand -> #<CL-JUPYTER-USER::VSTRAND>
# duplex num 10
# Starting function
# Starting loop
# duplex num 1
# Starting function
# Starting loop
# duplex num 11
# Starting function
# Starting loop
# duplex num 4
# Starting function
# Starting loop
# duplex num 8
# Starting function
# Starting loop
# duplex num 9
# Starting function
# Starting loop
# duplex num 5
# Starting function
# Starting loop
# duplex num 7
# Starting function
# Starting loop
# duplex num 3
# Starting function
# Starting loop
# duplex num 0
# Starting function
# ...

# %%
*origami*
# Out:
# #<HASH-TABLE-EQL :count 12 :total-alist-entries 12 @0xbb5d918>

# %%
(draw-graph "graph.dot" *origami*)
# Out:
# NIL

# %%
(draw-result-graph "graphr.dot" *origami*)
# Out:
# NIL

# %%
;(cmp:safe-system "dot -Tpng -O graph.dot")
# Out:
# ...
# NIL

# %%
(png-from-file "graph.dot.png")
# Out:
# #<CL-JUPYTER-USER::PNG-BYTES>

# %%
(arrow-direction (scaffold-vec (gethash 0 *origami*)))
# Out:
# (NIL -1 -1 -1 NIL -1 -1 -4 -1 -1 -1 -1)

# %%
(single-or-double-strand *origami*)
# Out:
# SIMPLE-PROGRAM-ERROR:
# Could not find variable P-NODE in lexical/global environment
# NIL
